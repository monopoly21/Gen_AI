# %% [markdown]
# #1. Implement logistic regression on admission dataset and diabetes dataset.
#
# #2. Implement Support Vector Machine classifer on IRIS and Heart dataset.
#
# #3. Implement k-means clustering algorithm on IRIS dataset. Use the elbow method for finding the optimal number of clusters.

# %%
# from sklearn.datasets import load_iris
# from sklearn.svm import SVC
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import classification_report
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# iris=load_iris()
# X=iris.data
# Y=iris.target

# scaler=StandardScaler()
# X_iris_scaled=scaler.fit_transform(X)

# X_train,X_test,Y_train,Y_test=train_test_split(X_iris_scaled,Y,train_size=0.2,random_state=42)

# svm=SVC(kernel='linear',C=1.0,random_state=42)
# svm.fit(X_train,Y_train)
# y_pred=svm.predict(X_test)
# iris_report=classification_report(Y_test,y_pred,target_names=iris.target_names)

# iris_report

from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


iris=load_iris()

X=iris.data
y=iris.target

scaler=StandardScaler()
X_iris_scaled=scaler.fit_transform(X)

X_train,X_test,y_train,y_test=train_test_split(X_iris_scaled,Y,train_size=0.2,random_state=42)

svm=SVC(kernel='linear',C=1.0,random_state=42)
svm.fit(X_train,y_train)
y_pred=svm.predict(X_test)
iris_rep=classification_report(y_pred,y_test,target_names=iris.target_names)

print(iris_rep)
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        43
#   versicolor       0.92      1.00      0.96        36
#    virginica       1.00      0.93      0.96        41
#
#     accuracy                           0.97       120
#    macro avg       0.97      0.98      0.97       120
# weighted avg       0.98      0.97      0.98       120

# %%
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

iris_data=load_iris()
X=iris.data

df=pd.DataFrame(X,columns=iris.feature_names)
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

inertia=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,random_state=42,n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)
K=range(1,11)
plt.plot(K,inertia,'bs-',label="inertia")
plt.legend()
plt.grid(True)
plt.show()

knee=KMeans(n_clusters=7,n_init=10,random_state=42)
knee.fit(X_scaled)
clusters=knee.predict(X_scaled)

plt.figure(figsize=(10,6))
plt.scatter(df.iloc[:,0],df.iloc[:,1],c=clusters)
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.plot()
# Out:
# []
